Total Yards Received

O 13.5
-110

U 13.5
-118
Justin
Watson
Kansas City Chiefs
Sun
KC Chiefs
@
CAR Panthers
Total Yards Received

O 13.5
-115

U 13.5
-113
Jalen
Nailor
Minnesota Vikings
Sun
MIN Vikings
@
CHI Bears
Total Yards Received

O 12.5
-112

U 12.5
-117
Tyrone
Tracy Jr.
New York Giants
Sun
TB Buccaneers
@
NY Giants
Total Yards Received

O 9.5
-122

U 9.5
-107
Jonathan
Taylor
Indianapolis Colts
Sun
DET Lions
@
IND Colts
Total Yards Received

O 8.5
-122

U 8.5
-107
Kareem
Hunt
Kansas City Chiefs
Sun
KC Chiefs
@
CAR Panthers
Total Yards Received

O 6.5
-112

U 6.5
-117
Brian
Robinson Jr.
Washington Commanders
Sun
DAL Cowboys
@
WAS Commanders
Total Yards Received

O 5.5
-114

U 5.5
-114
Ladd
McConkey
LA Chargers
Mon
BAL Ravens
@
LA Chargers
Total Yards Received

O 68.5
-115

U 68.5
-113
Zay
Flowers
Baltimore Ravens
Mon
BAL Ravens
@
LA Chargers
Total Yards Received

O 58.5
-113

U 58.5
-115
Quentin
Johnston
LA Chargers
Mon
BAL Ravens
@
LA Chargers
Total Yards Received

O 48.5
-117

U 48.5
-112
Will
Dissly
LA Chargers
Mon
BAL Ravens
@
LA Chargers
Total Yards Received

O 43.5
-118

U 43.5
-110
Rashod
Bateman
Baltimore Ravens
Mon
BAL Ravens
@
LA Chargers
Total Yards Received

O 36.5
-115

U 36.5
-113
Josh
Palmer
LA Chargers
Mon
BAL Ravens
@
LA Chargers
Total Yards Received

O 34.5
-110

U 34.5
-118
Mark
Andrews
Baltimore Ravens
Mon
BAL Ravens
@
LA Chargers
Total Yards Received

O 32.5
-117

U 32.5
-112
Isaiah
Likely
Baltimore Ravens
Mon
BAL Ravens
@
LA Chargers
Total Yards Received

O 27.5
-115

U 27.5
-113
J.K.
Dobbins
LA Chargers
Mon
BAL Ravens
@
LA Chargers
Total Yards Received

O 14.5
-121

U 14.5
-108
'''

# %%
import re
import pandas as pd

def extract_passing_lines(pass_input):
    # Regex pattern to capture the player's first name, last name, team, and "Over" value
    pattern = re.compile(
        r"(?P<first_name>\w+)\n"           # First name
        r"(?P<last_name>[^\n]+)\n"         # Last name
        r"(?P<team>[^\n]+)\n"              # Team name
        r"[^\n]+\n[^\n]+\n@\n[^\n]+\n"     # Skip match details
        r"Total Passing Yards Thrown\n\n"
        r"O (?P<over_value>[\d.]+)"        # "Over" value
    )
    
    # List to store each player's information as dictionaries
    player_data = []

    # Iterate over all matches and extract necessary data
    for match in pattern.finditer(pass_input):
        first_name = match.group("first_name")
        last_name = match.group("last_name")
        team = match.group("team")
        over_value = float(match.group("over_value"))  # Convert over value to float
        
        # Debugging: Print each extracted match
        # print(f"Match found: {first_name} {last_name}, Team: {team}, Over Value: {over_value}")

        # Append data as a dictionary
        player_data.append({
            "Player": f"{first_name} {last_name}",
            "Team": team,
            "Over Value": over_value
        })

    # Check if player data is populated
    if not player_data:
        print("No matches found in the input text.")

    # Create a DataFrame from the list of dictionaries
    pass_df = pd.DataFrame(player_data)

    pass_df.columns = ['player','team','line']
    pass_df['market'] = 'passing_yards'
    pass_df = pass_df[['player','market','line']]


    return pass_df

# rushing
def extract_rushing_lines(rush_input):
    # Regex pattern to capture the player's first name, last name, team, and "Over" value
    pattern = re.compile(
        r"(?P<first_name>\w+)\n"           # First name
        r"(?P<last_name>[^\n]+)\n"         # Last name
        r"(?P<team>[^\n]+)\n"              # Team name
        r"[^\n]+\n[^\n]+\n@\n[^\n]+\n"     # Skip match details
        r"Total Rushing Yards Recorded\n\n"
        r"O (?P<over_value>[\d.]+)"        # "Over" value
    )
    
    # List to store each player's information as dictionaries
    player_data = []

    # Iterate over all matches and extract necessary data
    for match in pattern.finditer(rush_input):
        first_name = match.group("first_name")
        last_name = match.group("last_name")
        team = match.group("team")
        over_value = float(match.group("over_value"))  # Convert over value to float
        
        # Debugging: Print each extracted match
        # print(f"Match found: {first_name} {last_name}, Team: {team}, Over Value: {over_value}")

        # Append data as a dictionary
        player_data.append({
            "Player": f"{first_name} {last_name}",
            "Team": team,
            "Over Value": over_value
        })

    # Check if player data is populated
    if not player_data:
        print("No matches found in the input text.")

    # Create a DataFrame from the list of dictionaries
    rush_df = pd.DataFrame(player_data)

    rush_df.columns = ['player','team','line']
    rush_df['market'] = 'rushing_yards'
    rush_df = rush_df[['player','market','line']]

    return rush_df

# receiving
def extract_receiving_lines(rec_input):
    # Regex pattern to capture the player's first name, last name, team, and "Over" value
    pattern = re.compile(
        r"(?P<first_name>\w+)\n"           # First name
        r"(?P<last_name>[^\n]+)\n"         # Last name
        r"(?P<team>[^\n]+)\n"              # Team name
        r"[^\n]+\n[^\n]+\n@\n[^\n]+\n"     # Skip match details
        r"Total Yards Received\n\n"
        r"O (?P<over_value>[\d.]+)"        # "Over" value
    )
    
    # List to store each player's information as dictionaries
    player_data = []

    # Iterate over all matches and extract necessary data
    for match in pattern.finditer(rec_input):
        first_name = match.group("first_name")
        last_name = match.group("last_name")
        team = match.group("team")
        over_value = float(match.group("over_value"))  # Convert over value to float
        
        # Debugging: Print each extracted match
        # print(f"Match found: {first_name} {last_name}, Team: {team}, Over Value: {over_value}")

        # Append data as a dictionary
        player_data.append({
            "Player": f"{first_name} {last_name}",
            "Team": team,
            "Over Value": over_value
        })

    # Check if player data is populated
    if not player_data:
        print("No matches found in the input text.")

    # Create a DataFrame from the list of dictionaries
    rec_df = pd.DataFrame(player_data)

    # clean rec input
    rec_df.columns = ['player','team','line']
    rec_df['market'] = 'receiving_yards'
    rec_df = rec_df[['player','market','line']]

    return rec_df

# %%
pd.concat([
    extract_passing_lines(pass_input),
    extract_rushing_lines(rush_input),
    extract_receiving_lines(rec_input)
]).to_csv(r'C:\Users\mikej\Desktop\underdog\br_lines.csv',index=False)
