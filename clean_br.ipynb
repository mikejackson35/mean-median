        r"(?P<first_name>\w+)\n"           # First name
        r"(?P<last_name>[^\n]+)\n"         # Last name
        r"(?P<team>[^\n]+)\n"              # Team name
        r"[^\n]+\n[^\n]+\n@\n[^\n]+\n"     # Skip match details
        r"Total Rushing Yards Recorded\n\n"
        r"O (?P<over_value>[\d.]+)"        # "Over" value
    )
    
    # List to store each player's information as dictionaries
    player_data = []

    # Iterate over all matches and extract necessary data
    for match in pattern.finditer(input_text):
        first_name = match.group("first_name")
        last_name = match.group("last_name")
        team = match.group("team")
        over_value = float(match.group("over_value"))  # Convert over value to float
        
        # Debugging: Print each extracted match
        # print(f"Match found: {first_name} {last_name}, Team: {team}, Over Value: {over_value}")

        # Append data as a dictionary
        player_data.append({
            "Player": f"{first_name} {last_name}",
            "Team": team,
            "Over Value": over_value
        })

    # Check if player data is populated
    if not player_data:
        print("No matches found in the input text.")

    # Create a DataFrame from the list of dictionaries
    df = pd.DataFrame(player_data)

    return df
# Out:
#                  player         market  line
# 0        Saquon Barkley  rushing_yards  94.5
# 1    Brian Robinson Jr.  rushing_yards  45.5
# 2           Jalen Hurts  rushing_yards  40.5
# 3        Jayden Daniels  rushing_yards  39.5
# 4         Derrick Henry  rushing_yards  85.5
# 5        Kyren Williams  rushing_yards  82.5
# 6   Christian McCaffrey  rushing_yards  81.5
# 7          Alvin Kamara  rushing_yards  72.5
# 8           Kareem Hunt  rushing_yards  64.5
# 9            Von Achane  rushing_yards  62.5
# 10           Nick Chubb  rushing_yards  60.5
# 11           James Cook  rushing_yards  57.5
# 12          Aaron Jones  rushing_yards  57.5
# 13  Rhamondre Stevenson  rushing_yards  55.5
# 14   Kenneth Walker III  rushing_yards  54.5
# 15        Lamar Jackson  rushing_yards  43.5
# 16           Josh Allen  rushing_yards  34.5
# 17           Drake Maye  rushing_yards  29.5
# 18          Taysom Hill  rushing_yards  25.5
# 19      Patrick Mahomes  rushing_yards  21.5
# ...

# %%
# clean rush input
rush_dict = extract_player_over_values(rush_input)
rush_df = pd.DataFrame(rush_dict)
rush_df.columns = ['player','team','line']
rush_df['market'] = 'rushing_yards'
rush_df = rush_df[['player','market','line']]

# clean rec input
rec_dict = extract_player_over_values(rec_input)
rec_df = pd.DataFrame(rec_dict)
rec_df.columns = ['player','team','line']
rec_df['market'] = 'rushing_yards'
rec_df = rec_df[['player','market','line']]

# clean pass input
pass_dict = extract_player_over_values(pass_input)
pass_df = pd.DataFrame(pass_dict)
pass_df.columns = ['player','team','line']
pass_df['market'] = 'rushing_yards'
pass_df = pass_df[['player','market','line']]

pd.concat([rush_df,rec_df,pass_df])
# Out:
# No matches found in the input text.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 11
#       9 rec_dict = extract_player_over_values(rec_input)
#      10 rec_df = pd.DataFrame(rec_dict)
# ---> 11 rec_df.columns = ['player','team','line']
#      12 rec_df['market'] = 'rushing_yards'
#      13 rec_df = rec_df[['player','market','line']]
#
# File c:\Users\mikej\anaconda3\Lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File c:\Users\mikej\anaconda3\Lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# ...

# %%
pass_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pass_df
#
# NameError: name 'pass_df' is not defined

# %%
df
